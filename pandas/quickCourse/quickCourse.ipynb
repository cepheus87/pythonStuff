# %%
import os
os.listdir()
# Out:
# ['supermarkets-semi-colons.txt',
#  'supermarkets.json',
#  'reading.ipynb',
#  'supermarkets.xlsx',
#  'supermarkets-commas.txt',
#  '.ipynb_checkpoints',
#  'supermarkets.csv']

# %%
import pandas as pd

# %%
df_csv = pd.read_csv("supermarkets.csv")
df_csv.head()
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12

# %%
df_csv.set_index("ID", inplace=True)
df_csv.head()
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12

# %%
df_csv.shape
# Out:
# (6, 6)

# %%
df_json = pd.read_json("supermarkets.json")
df_json.head()
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California

# %%
df_excel = pd.read_excel("supermarkets.xlsx", sheetname=0)
df_excel.head()
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12

# %%
df_com = pd.read_csv("supermarkets-commas.txt")
df_com.head()
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12

# %%
pd.read_csv?

# %%
df_semicol = pd.read_csv("supermarkets-semi-colons.txt", sep=";")
df_semicol.head()
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12

# %%
df = pd.read_csv("http://pythonhow.com/supermarkets.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-c44dfe5160bd> in <module>()
# ----> 1 df = pd.read_csv("http://pythonhow.com/supermarkets.json")
#       2 df.head()
#
# ...

# %%
df = df_csv
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.loc[2:4, "City":"Name"]
# Out:
#              City             State Country         Name
# ID
# 2   San Francisco          CA 94119     USA  Bready Shop
# 3   San Francisco  California 94114     USA  Super River
# 4   San Francisco          CA 94114     USA   Ben's Shop

# %%
df.iloc[2:4, 1:3]
# Out:
#              City             State
# ID
# 3   San Francisco  California 94114
# 4   San Francisco          CA 94114

# %%
df.ix[0:2, "Name"]
# Out:
# /home/tomasz_bednarski/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ID
# 1        Madeira
# 2    Bready Shop
# Name: Name, dtype: object

# %%
df.drop("City", 1) # columns
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df.drop(df.columns[1:4], 1) # columns
# Out:
#             Address         Name  Employees
# ID
# 1      3666 21st St      Madeira          8
# 2    735 Dolores St  Bready Shop         15
# 3       332 Hill St  Super River         25
# 4      3995 23rd St   Ben's Shop         10
# 5   1056 Sanchez St      Sanchez         12
# 6   551 Alvarado St   Richvalley         20

# %%
df.drop(1, axis=0) # row
# Out:
#             Address           City             State Country         Name  \
# ID
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.drop(df.index[2:4], axis=0) # row
# Out:
#             Address           City       State Country         Name  Employees
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira          8
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
df["Continent"] = df.shape[0] * ["North America"]
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df.drop("Continent", 1, inplace=True)
df["Continent"] = len(df.index) * ["North America"]
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %% [markdown]
# to add row : transpose, add column and transpose again
